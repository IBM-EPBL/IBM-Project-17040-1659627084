# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
df=pd.read_csv('/content/drive/MyDrive/attrition/employee_attrition_train.csv')

# %%
df
# Out:
#        Age Attrition     BusinessTravel  DailyRate              Department  \
# 0     50.0        No      Travel_Rarely     1126.0  Research & Development
# 1     36.0        No      Travel_Rarely      216.0  Research & Development
# 2     21.0       Yes      Travel_Rarely      337.0                   Sales
# 3     50.0        No  Travel_Frequently     1246.0         Human Resources
# 4     52.0        No      Travel_Rarely      994.0  Research & Development
# ...    ...       ...                ...        ...                     ...
# 1024   NaN        No      Travel_Rarely      750.0  Research & Development
# 1025  41.0        No      Travel_Rarely      447.0  Research & Development
# 1026  22.0       Yes  Travel_Frequently     1256.0  Research & Development
# 1027  29.0        No      Travel_Rarely     1378.0  Research & Development
# 1028  50.0        No      Travel_Rarely      264.0                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                  1.0          2        Medical              1
# 1                  6.0          2        Medical              1
# 2                  7.0          1      Marketing              1
# 3                  NaN          3        Medical              1
# 4                  7.0          4  Life Sciences              1
# ...                ...        ...            ...            ...
# 1024              28.0          3  Life Sciences              1
# 1025               NaN          3  Life Sciences              1
# 1026               NaN          4  Life Sciences              1
# 1027              13.0          2          Other              1
# 1028               9.0          3      Marketing              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                997  ...                         3            80
# 1                178  ...                         4            80
# 2               1780  ...                         2            80
# 3                644  ...                         3            80
# 4               1118  ...                         4            80
# ...              ...  ...                       ...           ...
# 1024            1596  ...                         4            80
# 1025            1814  ...                         1            80
# 1026            1203  ...                         2            80
# 1027            2053  ...                         1            80
# 1028            1591  ...                         3            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    1                 32                      1
# 1                    2                  7                      0
# 2                    0                  1                      3
# 3                    1                 32                      2
# 4                    0                 18                      4
# ...                ...                ...                    ...
# 1024                 2                 10                      3
# 1025                 0                 11                      3
# 1026                 1                  1                      5
# 1027                 1                 10                      2
# 1028                 1                 27                      2
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  2               5                  4
# 1                  3               3                  2
# 2                  3               1                  0
# 3                  3              32                  5
# 4                  3               8                  6
# ...              ...             ...                ...
# 1024               2              10                  9
# 1025               1               3                  2
# 1026               3               0                  0
# 1027               3               4                  3
# 1028               3               1                  0
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           1                     3
# 1                           0                     1
# 2                           1                     0
# 3                          10                     7
# 4                           4                     0
# ...                       ...                   ...
# 1024                        6                     8
# 1025                        1                     2
# 1026                        0                     0
# 1027                        0                     3
# 1028                        0                     0
#
# [1029 rows x 35 columns]

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.shape
# Out:
# (1029, 35)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1029 entries, 0 to 1028
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       893 non-null    float64
#  1   Attrition                 1029 non-null   object
#  2   BusinessTravel            1024 non-null   object
#  3   DailyRate                 1002 non-null   float64
#  4   Department                1029 non-null   object
#  5   DistanceFromHome          934 non-null    float64
#  6   Education                 1029 non-null   int64
#  7   EducationField            1029 non-null   object
#  8   EmployeeCount             1029 non-null   int64
#  9   EmployeeNumber            1029 non-null   int64
#  10  EnvironmentSatisfaction   1029 non-null   int64
#  11  Gender                    1029 non-null   object
#  12  HourlyRate                1029 non-null   int64
#  13  JobInvolvement            1029 non-null   int64
#  14  JobLevel                  1029 non-null   int64
#  15  JobRole                   1029 non-null   object
#  16  JobSatisfaction           1029 non-null   int64
#  17  MaritalStatus             1024 non-null   object
#  18  MonthlyIncome             1029 non-null   int64
#  19  MonthlyRate               1029 non-null   int64
#  20  NumCompaniesWorked        1029 non-null   int64
#  21  Over18                    1029 non-null   object
#  22  OverTime                  1029 non-null   object
#  23  PercentSalaryHike         1029 non-null   int64
#  24  PerformanceRating         1029 non-null   int64
#  25  RelationshipSatisfaction  1029 non-null   int64
#  26  StandardHours             1029 non-null   int64
#  27  StockOptionLevel          1029 non-null   int64
#  28  TotalWorkingYears         1029 non-null   int64
#  29  TrainingTimesLastYear     1029 non-null   int64
#  30  WorkLifeBalance           1029 non-null   int64
#  31  YearsAtCompany            1029 non-null   int64
#  32  YearsInCurrentRole        1029 non-null   int64
#  33  YearsSinceLastPromotion   1029 non-null   int64
#  34  YearsWithCurrManager      1029 non-null   int64
# dtypes: float64(3), int64(23), object(9)
# memory usage: 281.5+ KB

# %%
df.describe()
# Out:
#               Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  893.000000  1002.000000        934.000000  1029.000000         1029.0
# mean    37.930571   800.528942          9.930407     2.892128            1.0
# std      9.395978   408.109828          8.421791     1.053541            0.0
# min     18.000000   102.000000          1.000000     1.000000            1.0
# 25%     31.000000   458.250000          2.000000     2.000000            1.0
# 50%     37.000000   801.500000          8.000000     3.000000            1.0
# 75%     44.000000  1162.000000         16.000000     4.000000            1.0
# max     60.000000  1496.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1029.000000              1029.000000  1029.000000     1029.000000
# mean      1024.367347                 2.683188    66.680272        2.713314
# std        606.301635                 1.096829    20.474094        0.710146
# min          1.000000                 1.000000    30.000000        1.000000
# 25%        496.000000                 2.000000    48.000000        2.000000
# 50%       1019.000000                 3.000000    67.000000        3.000000
# 75%       1553.000000                 4.000000    84.000000        3.000000
# max       2068.000000                 4.000000   100.000000        4.000000
#
#           JobLevel  ...  RelationshipSatisfaction  StandardHours  \
# count  1029.000000  ...               1029.000000         1029.0
# mean      2.043732  ...                  2.689990           80.0
# std       1.118918  ...                  1.077767            0.0
# min       1.000000  ...                  1.000000           80.0
# 25%       1.000000  ...                  2.000000           80.0
# 50%       2.000000  ...                  3.000000           80.0
# 75%       3.000000  ...                  4.000000           80.0
# max       5.000000  ...                  4.000000           80.0
#
#        StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count       1029.000000        1029.000000            1029.000000
# mean           0.822157          11.196307               2.782313
# std            0.874662           7.857581               1.283401
# min            0.000000           0.000000               0.000000
# 25%            0.000000           6.000000               2.000000
# 50%            1.000000          10.000000               3.000000
# 75%            1.000000          15.000000               3.000000
# max            3.000000          40.000000               6.000000
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count      1029.000000     1029.000000         1029.000000
# mean          2.748299        6.942663            4.215743
# std           0.697278        6.068322            3.658595
# min           1.000000        0.000000            0.000000
# 25%           2.000000        3.000000            2.000000
# 50%           3.000000        5.000000            3.000000
# 75%           3.000000       10.000000            7.000000
# max           4.000000       37.000000           18.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# count              1029.000000           1029.000000
# mean                  2.119534              4.005831
# std                   3.108651              3.522574
# min                   0.000000              0.000000
# 25%                   0.000000              2.000000
# 50%                   1.000000              3.000000
# 75%                   2.000000              7.000000
# max                  15.000000             17.000000
#
# [8 rows x 26 columns]

# %%
df.isnull().sum()
# Out:
# Age                         136
# Attrition                     0
# BusinessTravel                5
# DailyRate                    27
# Department                    0
# DistanceFromHome             95
# Education                     0
# EducationField                0
# EmployeeCount                 0
# EmployeeNumber                0
# EnvironmentSatisfaction       0
# Gender                        0
# HourlyRate                    0
# JobInvolvement                0
# JobLevel                      0
# JobRole                       0
# JobSatisfaction               0
# MaritalStatus                 5
# MonthlyIncome                 0
# MonthlyRate                   0
# NumCompaniesWorked            0
# Over18                        0
# OverTime                      0
# PercentSalaryHike             0
# PerformanceRating             0
# RelationshipSatisfaction      0
# StandardHours                 0
# StockOptionLevel              0
# TotalWorkingYears             0
# TrainingTimesLastYear         0
# WorkLifeBalance               0
# YearsAtCompany                0
# YearsInCurrentRole            0
# YearsSinceLastPromotion       0
# YearsWithCurrManager          0
# dtype: int64

# %%
df['NumCompaniesWorked']=df['NumCompaniesWorked'].fillna(df['NumCompaniesWorked'].mean())

# %%
df['TotalWorkingYears']=df['TotalWorkingYears'].fillna(df['TotalWorkingYears'].mean())

# %%
df.isnull().sum()
# Out:
# Age                         136
# Attrition                     0
# BusinessTravel                5
# DailyRate                    27
# Department                    0
# DistanceFromHome             95
# Education                     0
# EducationField                0
# EmployeeCount                 0
# EmployeeNumber                0
# EnvironmentSatisfaction       0
# Gender                        0
# HourlyRate                    0
# JobInvolvement                0
# JobLevel                      0
# JobRole                       0
# JobSatisfaction               0
# MaritalStatus                 5
# MonthlyIncome                 0
# MonthlyRate                   0
# NumCompaniesWorked            0
# Over18                        0
# OverTime                      0
# PercentSalaryHike             0
# PerformanceRating             0
# RelationshipSatisfaction      0
# StandardHours                 0
# StockOptionLevel              0
# TotalWorkingYears             0
# TrainingTimesLastYear         0
# WorkLifeBalance               0
# YearsAtCompany                0
# YearsInCurrentRole            0
# YearsSinceLastPromotion       0
# YearsWithCurrManager          0
# dtype: int64

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.head()
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0  50.0        No      Travel_Rarely     1126.0  Research & Development
# 1  36.0        No      Travel_Rarely      216.0  Research & Development
# 2  21.0       Yes      Travel_Rarely      337.0                   Sales
# 3  50.0        No  Travel_Frequently     1246.0         Human Resources
# 4  52.0        No      Travel_Rarely      994.0  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0               1.0          2        Medical              1             997
# 1               6.0          2        Medical              1             178
# 2               7.0          1      Marketing              1            1780
# 3               NaN          3        Medical              1             644
# 4               7.0          4  Life Sciences              1            1118
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         3            80                 1
# 1  ...                         4            80                 2
# 2  ...                         2            80                 0
# 3  ...                         3            80                 1
# 4  ...                         4            80                 0
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                 32                      1               2               5
# 1                  7                      0               3               3
# 2                  1                      3               3               1
# 3                 32                      2               3              32
# 4                 18                      4               3               8
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        1                     3
# 1                  2                        0                     1
# 2                  0                        1                     0
# 3                  5                       10                     7
# 4                  6                        4                     0
#
# [5 rows x 35 columns]

# %%
df['Attrition'].value_counts()
# Out:
# No     853
# Yes    176
# Name: Attrition, dtype: int64

# %%
sns.countplot(df['Attrition'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
fig_dims = (12, 4)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(x='Age', hue='Attrition', data = df, palette="colorblind", ax = ax,  edgecolor=sns.color_palette("dark", n_colors = 1));

# %%
for column in df.columns:
    if df[column].dtype == object:
        print(str(column) + ' : ' + str(df[column].unique()))
        print(df[column].value_counts())
# Out:
# Attrition : ['No' 'Yes']
# No     853
# Yes    176
# Name: Attrition, dtype: int64
# BusinessTravel : ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel' nan]
# Travel_Rarely        723
# Travel_Frequently    199
# Non-Travel           102
# Name: BusinessTravel, dtype: int64
# Department : ['Research & Development' 'Sales' 'Human Resources']
# Research & Development    676
# Sales                     311
# Human Resources            42
# Name: Department, dtype: int64
# EducationField : ['Medical' 'Marketing' 'Life Sciences' 'Technical Degree'
#  'Human Resources' 'Other']
# Life Sciences       426
# Medical             328
# Marketing           110
# Technical Degree     82
# Other                66
# Human Resources      17
# Name: EducationField, dtype: int64
# Gender : ['Male' 'Female']
# Male      617
# Female    412
# Name: Gender, dtype: int64
# JobRole : ['Research Director' 'Manufacturing Director' 'Sales Representative'
#  'Manager' 'Healthcare Representative' 'Research Scientist'
#  'Sales Executive' 'Laboratory Technician' 'Human Resources']
# Sales Executive              217
# Research Scientist           214
# Laboratory Technician        179
# Manufacturing Director        95
# Healthcare Representative     89
# Manager                       73
# Sales Representative          66
# Research Director             62
# Human Resources               34
# Name: JobRole, dtype: int64
# MaritalStatus : ['Divorced' 'Single' 'Married' nan]
# Married     474
# Single      320
# Divorced    230
# Name: MaritalStatus, dtype: int64
# Over18 : ['Y']
# Y    1029
# Name: Over18, dtype: int64
# OverTime : ['No' 'Yes']
# No     731
# Yes    298
# Name: OverTime, dtype: int64

# %%
df = df.drop('StandardHours', axis = 1) #Contains only value 80 
df = df.drop('EmployeeCount', axis = 1) #Contains only the value 1 
df = df.drop('Over18', axis = 1) #Contains only the value 'Yes'

# %%
df
# Out:
#        Age Attrition     BusinessTravel  DailyRate              Department  \
# 0     50.0        No      Travel_Rarely     1126.0  Research & Development
# 1     36.0        No      Travel_Rarely      216.0  Research & Development
# 2     21.0       Yes      Travel_Rarely      337.0                   Sales
# 3     50.0        No  Travel_Frequently     1246.0         Human Resources
# 4     52.0        No      Travel_Rarely      994.0  Research & Development
# ...    ...       ...                ...        ...                     ...
# 1024   NaN        No      Travel_Rarely      750.0  Research & Development
# 1025  41.0        No      Travel_Rarely      447.0  Research & Development
# 1026  22.0       Yes  Travel_Frequently     1256.0  Research & Development
# 1027  29.0        No      Travel_Rarely     1378.0  Research & Development
# 1028  50.0        No      Travel_Rarely      264.0                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                  1.0          2        Medical             997
# 1                  6.0          2        Medical             178
# 2                  7.0          1      Marketing            1780
# 3                  NaN          3        Medical             644
# 4                  7.0          4  Life Sciences            1118
# ...                ...        ...            ...             ...
# 1024              28.0          3  Life Sciences            1596
# 1025               NaN          3  Life Sciences            1814
# 1026               NaN          4  Life Sciences            1203
# 1027              13.0          2          Other            2053
# 1028               9.0          3      Marketing            1591
#
#       EnvironmentSatisfaction  ... PerformanceRating  \
# 0                           4  ...                 4
# 1                           2  ...                 4
# 2                           2  ...                 3
# 3                           1  ...                 3
# 4                           2  ...                 3
# ...                       ...  ...               ...
# 1024                        2  ...                 3
# 1025                        2  ...                 3
# 1026                        3  ...                 3
# 1027                        4  ...                 3
# 1028                        3  ...                 3
#
#       RelationshipSatisfaction  StockOptionLevel  TotalWorkingYears  \
# 0                            3                 1                 32
# 1                            4                 2                  7
# 2                            2                 0                  1
# 3                            3                 1                 32
# 4                            4                 0                 18
# ...                        ...               ...                ...
# 1024                         4                 2                 10
# 1025                         1                 0                 11
# 1026                         2                 1                  1
# 1027                         1                 1                 10
# 1028                         3                 1                 27
#
#      TrainingTimesLastYear  WorkLifeBalance YearsAtCompany  \
# 0                        1                2              5
# 1                        0                3              3
# 2                        3                3              1
# 3                        2                3             32
# 4                        4                3              8
# ...                    ...              ...            ...
# 1024                     3                2             10
# 1025                     3                1              3
# 1026                     5                3              0
# 1027                     2                3              4
# 1028                     2                3              1
#
#       YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                      4                        1                     3
# 1                      2                        0                     1
# 2                      0                        1                     0
# 3                      5                       10                     7
# 4                      6                        4                     0
# ...                  ...                      ...                   ...
# 1024                   9                        6                     8
# 1025                   2                        1                     2
# 1026                   0                        0                     0
# 1027                   3                        0                     3
# 1028                   0                        0                     0
#
# [1029 rows x 32 columns]

# %%
df.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.023845         -0.036895   0.226646
# DailyRate                 0.023845   1.000000         -0.018783  -0.056701
# DistanceFromHome         -0.036895  -0.018783          1.000000   0.005009
# Education                 0.226646  -0.056701          0.005009   1.000000
# EmployeeNumber           -0.014892  -0.054757          0.041360   0.058632
# EnvironmentSatisfaction  -0.024051  -0.001438         -0.041260  -0.032129
# HourlyRate                0.019754   0.028555         -0.007381   0.012786
# JobInvolvement            0.024176   0.047225          0.026350   0.049639
# JobLevel                  0.506348   0.021386          0.002220   0.093952
# JobSatisfaction           0.007670   0.022260          0.015920   0.001742
# MonthlyIncome             0.492360   0.023055         -0.018486   0.093543
# MonthlyRate               0.018697  -0.003860          0.061144  -0.052047
# NumCompaniesWorked        0.298354   0.041677         -0.035275   0.119453
# PercentSalaryHike         0.011593   0.016684          0.051717  -0.007075
# PerformanceRating         0.007457   0.018240          0.041723  -0.025992
# RelationshipSatisfaction  0.062533   0.029849          0.014434  -0.005492
# StockOptionLevel          0.023282   0.049149          0.018559   0.025609
# TotalWorkingYears         0.676650   0.007548         -0.005680   0.159551
# TrainingTimesLastYear    -0.026077   0.022518         -0.040232  -0.041845
# WorkLifeBalance          -0.042949  -0.053567         -0.020954   0.018620
# YearsAtCompany            0.291798  -0.041877         -0.002579   0.070545
# YearsInCurrentRole        0.218028  -0.019262          0.003508   0.087055
# YearsSinceLastPromotion   0.178679  -0.049283         -0.024982   0.057998
# YearsWithCurrManager      0.186070  -0.056317          0.017107   0.083523
#
#                           EmployeeNumber  EnvironmentSatisfaction  HourlyRate  \
# Age                            -0.014892                -0.024051    0.019754
# DailyRate                      -0.054757                -0.001438    0.028555
# DistanceFromHome                0.041360                -0.041260   -0.007381
# Education                       0.058632                -0.032129    0.012786
# EmployeeNumber                  1.000000                 0.017413    0.032326
# EnvironmentSatisfaction         0.017413                 1.000000   -0.038216
# HourlyRate                      0.032326                -0.038216    1.000000
# JobInvolvement                  0.004476                -0.015561    0.043600
# JobLevel                       -0.036151                -0.005345   -0.047287
# JobSatisfaction                -0.043173                -0.045906   -0.091423
# MonthlyIncome                  -0.026493                -0.013881   -0.033674
# MonthlyRate                     0.014350                 0.067739    0.000859
# NumCompaniesWorked             -0.011233                -0.001804    0.008938
# PercentSalaryHike              -0.034833                -0.012362   -0.003659
# PerformanceRating              -0.054376                 0.002318   -0.002279
# RelationshipSatisfaction       -0.059879                -0.016510   -0.015076
# StockOptionLevel                0.041590                 0.006108    0.021483
# TotalWorkingYears              -0.018604                -0.002371   -0.015391
# TrainingTimesLastYear           0.009204                -0.004123   -0.001245
# WorkLifeBalance                 0.012589                 0.025369   -0.008096
# YearsAtCompany                 -0.009828                 0.015683   -0.036649
# YearsInCurrentRole             -0.018311                 0.019474   -0.027986
# YearsSinceLastPromotion        -0.025772                 0.035938   -0.058669
# YearsWithCurrManager           -0.006427                -0.009592   -0.029499
#
#                           JobInvolvement  JobLevel  JobSatisfaction  ...  \
# Age                             0.024176  0.506348         0.007670  ...
# DailyRate                       0.047225  0.021386         0.022260  ...
# DistanceFromHome                0.026350  0.002220         0.015920  ...
# Education                       0.049639  0.093952         0.001742  ...
# EmployeeNumber                  0.004476 -0.036151        -0.043173  ...
# EnvironmentSatisfaction        -0.015561 -0.005345        -0.045906  ...
# HourlyRate                      0.043600 -0.047287        -0.091423  ...
# JobInvolvement                  1.000000 -0.002570        -0.013561  ...
# JobLevel                       -0.002570  1.000000        -0.011140  ...
# JobSatisfaction                -0.013561 -0.011140         1.000000  ...
# MonthlyIncome                  -0.002592  0.952756        -0.020463  ...
# MonthlyRate                    -0.057787  0.048007        -0.001979  ...
# NumCompaniesWorked              0.014010  0.154803        -0.055757  ...
# PercentSalaryHike              -0.023604 -0.018906         0.018167  ...
# PerformanceRating              -0.044825 -0.007530         0.007691  ...
# RelationshipSatisfaction        0.038824  0.021739        -0.006388  ...
# StockOptionLevel                0.032162 -0.006955         0.007461  ...
# TotalWorkingYears               0.008527  0.786130        -0.020868  ...
# TrainingTimesLastYear          -0.009838 -0.001493         0.003154  ...
# WorkLifeBalance                -0.022104  0.051527        -0.041340  ...
# YearsAtCompany                 -0.009461  0.544920        -0.005842  ...
# YearsInCurrentRole              0.014094  0.418767         0.005784  ...
# YearsSinceLastPromotion        -0.039542  0.350313        -0.016437  ...
# YearsWithCurrManager            0.049666  0.365449        -0.017440  ...
#
#                           PerformanceRating  RelationshipSatisfaction  \
# Age                                0.007457                  0.062533
# DailyRate                          0.018240                  0.029849
# DistanceFromHome                   0.041723                  0.014434
# Education                         -0.025992                 -0.005492
# EmployeeNumber                    -0.054376                 -0.059879
# EnvironmentSatisfaction            0.002318                 -0.016510
# HourlyRate                        -0.002279                 -0.015076
# JobInvolvement                    -0.044825                  0.038824
# JobLevel                          -0.007530                  0.021739
# JobSatisfaction                    0.007691                 -0.006388
# MonthlyIncome                     -0.010082                  0.032840
# MonthlyRate                       -0.012428                 -0.005242
# NumCompaniesWorked                 0.006246                  0.032144
# PercentSalaryHike                  0.774110                 -0.046514
# PerformanceRating                  1.000000                 -0.044754
# RelationshipSatisfaction          -0.044754                  1.000000
# StockOptionLevel                   0.000505                 -0.038936
# TotalWorkingYears                  0.022584                  0.024653
# TrainingTimesLastYear             -0.013038                 -0.002421
# WorkLifeBalance                   -0.025604                  0.039748
# YearsAtCompany                    -0.005514                  0.020780
# YearsInCurrentRole                 0.032395                 -0.000044
# YearsSinceLastPromotion            0.029392                  0.044460
# YearsWithCurrManager               0.015115                 -0.006185
#
#                           StockOptionLevel  TotalWorkingYears  \
# Age                               0.023282           0.676650
# DailyRate                         0.049149           0.007548
# DistanceFromHome                  0.018559          -0.005680
# Education                         0.025609           0.159551
# EmployeeNumber                    0.041590          -0.018604
# EnvironmentSatisfaction           0.006108          -0.002371
# HourlyRate                        0.021483          -0.015391
# JobInvolvement                    0.032162           0.008527
# JobLevel                         -0.006955           0.786130
# JobSatisfaction                   0.007461          -0.020868
# MonthlyIncome                    -0.007745           0.773499
# MonthlyRate                      -0.021333           0.021179
# NumCompaniesWorked                0.034812           0.261898
# PercentSalaryHike                 0.010213           0.003086
# PerformanceRating                 0.000505           0.022584
# RelationshipSatisfaction         -0.038936           0.024653
# StockOptionLevel                  1.000000           0.002395
# TotalWorkingYears                 0.002395           1.000000
# TrainingTimesLastYear             0.034804          -0.013314
# WorkLifeBalance                   0.028612           0.005121
# YearsAtCompany                    0.011822           0.624096
# YearsInCurrentRole                0.056079           0.480783
# YearsSinceLastPromotion          -0.007916           0.384496
# YearsWithCurrManager              0.019912           0.448262
#
#                           TrainingTimesLastYear  WorkLifeBalance  \
# Age                                   -0.026077        -0.042949
# DailyRate                              0.022518        -0.053567
# DistanceFromHome                      -0.040232        -0.020954
# Education                             -0.041845         0.018620
# EmployeeNumber                         0.009204         0.012589
# EnvironmentSatisfaction               -0.004123         0.025369
# HourlyRate                            -0.001245        -0.008096
# JobInvolvement                        -0.009838        -0.022104
# JobLevel                              -0.001493         0.051527
# JobSatisfaction                        0.003154        -0.041340
# MonthlyIncome                         -0.002389         0.040840
# MonthlyRate                           -0.002454        -0.008156
# NumCompaniesWorked                    -0.075764        -0.008264
# PercentSalaryHike                     -0.003445        -0.029130
# PerformanceRating                     -0.013038        -0.025604
# RelationshipSatisfaction              -0.002421         0.039748
# StockOptionLevel                       0.034804         0.028612
# TotalWorkingYears                     -0.013314         0.005121
# TrainingTimesLastYear                  1.000000         0.031110
# WorkLifeBalance                        0.031110         1.000000
# YearsAtCompany                         0.015383         0.020725
# YearsInCurrentRole                     0.022235         0.053338
# YearsSinceLastPromotion                0.006041         0.033640
# YearsWithCurrManager                   0.011255        -0.003758
#
#                           YearsAtCompany  YearsInCurrentRole  \
# Age                             0.291798            0.218028
# DailyRate                      -0.041877           -0.019262
# DistanceFromHome               -0.002579            0.003508
# Education                       0.070545            0.087055
# EmployeeNumber                 -0.009828           -0.018311
# EnvironmentSatisfaction         0.015683            0.019474
# HourlyRate                     -0.036649           -0.027986
# JobInvolvement                 -0.009461            0.014094
# JobLevel                        0.544920            0.418767
# JobSatisfaction                -0.005842            0.005784
# MonthlyIncome                   0.525311            0.396541
# MonthlyRate                    -0.021471            0.016096
# NumCompaniesWorked             -0.100946           -0.060422
# PercentSalaryHike              -0.014896            0.010240
# PerformanceRating              -0.005514            0.032395
# RelationshipSatisfaction        0.020780           -0.000044
# StockOptionLevel                0.011822            0.056079
# TotalWorkingYears               0.624096            0.480783
# TrainingTimesLastYear           0.015383            0.022235
# WorkLifeBalance                 0.020725            0.053338
# YearsAtCompany                  1.000000            0.777925
# YearsInCurrentRole              0.777925            1.000000
# YearsSinceLastPromotion         0.592912            0.545809
# YearsWithCurrManager            0.759755            0.705717
#
#                           YearsSinceLastPromotion  YearsWithCurrManager
# Age                                      0.178679              0.186070
# DailyRate                               -0.049283             -0.056317
# DistanceFromHome                        -0.024982              0.017107
# Education                                0.057998              0.083523
# EmployeeNumber                          -0.025772             -0.006427
# EnvironmentSatisfaction                  0.035938             -0.009592
# HourlyRate                              -0.058669             -0.029499
# JobInvolvement                          -0.039542              0.049666
# JobLevel                                 0.350313              0.365449
# JobSatisfaction                         -0.016437             -0.017440
# MonthlyIncome                            0.346647              0.336437
# MonthlyRate                              0.009966             -0.022441
# NumCompaniesWorked                      -0.025866             -0.090713
# PercentSalaryHike                        0.003155              0.000334
# PerformanceRating                        0.029392              0.015115
# RelationshipSatisfaction                 0.044460             -0.006185
# StockOptionLevel                        -0.007916              0.019912
# TotalWorkingYears                        0.384496              0.448262
# TrainingTimesLastYear                    0.006041              0.011255
# WorkLifeBalance                          0.033640             -0.003758
# YearsAtCompany                           0.592912              0.759755
# YearsInCurrentRole                       0.545809              0.705717
# YearsSinceLastPromotion                  1.000000              0.476615
# YearsWithCurrManager                     0.476615              1.000000
#
# [24 rows x 24 columns]

# %%
df.cov()
# Out:
#                                    Age      DailyRate  DistanceFromHome  \
# Age                          88.284412      91.483770         -2.828527
# DailyRate                    91.483770  166553.632029        -64.639450
# DistanceFromHome             -2.828527     -64.639450         70.926556
# Education                     2.263486     -24.292053          0.044734
# EmployeeNumber              -85.414709  -13489.024498        210.411278
# EnvironmentSatisfaction      -0.249372      -0.642567         -0.380837
# HourlyRate                    3.833538     238.047236         -1.268295
# JobInvolvement                0.160614      13.602559          0.159179
# JobLevel                      5.499858       9.796459          0.020953
# JobSatisfaction               0.079040       9.925121          0.147511
# MonthlyIncome             23085.825703   45297.209866       -748.756546
# MonthlyRate                1250.653646  -11183.028066       3652.693782
# NumCompaniesWorked            7.158091      42.434159         -0.748013
# PercentSalaryHike             0.398912      24.869597          1.611025
# PerformanceRating             0.025782       2.707249          0.130458
# RelationshipSatisfaction      0.633724      13.131073          0.130268
# StockOptionLevel              0.193061      17.535145          0.138119
# TotalWorkingYears            51.307847      24.198823         -0.378201
# TrainingTimesLastYear        -0.313929      11.778118         -0.433195
# WorkLifeBalance              -0.276014     -15.265970         -0.123489
# YearsAtCompany               17.313992    -104.131306         -0.132493
# YearsInCurrentRole            7.610359     -28.738166          0.108279
# YearsSinceLastPromotion       5.387640     -62.109487         -0.667696
# YearsWithCurrManager          6.302237     -80.934305          0.512384
#
#                            Education  EmployeeNumber  EnvironmentSatisfaction  \
# Age                         2.263486      -85.414709                -0.249372
# DailyRate                 -24.292053   -13489.024498                -0.642567
# DistanceFromHome            0.044734      210.411278                -0.380837
# Education                   1.109948       37.452116                -0.037127
# EmployeeNumber             37.452116   367601.672318                11.579528
# EnvironmentSatisfaction    -0.037127       11.579528                 1.203034
# HourlyRate                  0.275788      401.273207                -0.858202
# JobInvolvement              0.037138        1.927400                -0.012120
# JobLevel                    0.110753      -24.524835                -0.006560
# JobSatisfaction             0.002014      -28.712320                -0.055230
# MonthlyIncome             472.505306   -77014.545938               -72.995344
# MonthlyRate              -388.700486    61676.157548               526.682193
# NumCompaniesWorked          0.315652      -17.082546                -0.004963
# PercentSalaryHike          -0.027325      -77.419697                -0.049703
# PerformanceRating          -0.010028      -12.073195                 0.000931
# RelationshipSatisfaction   -0.006236      -39.128226                -0.019517
# StockOptionLevel            0.023599       22.055666                 0.005859
# TotalWorkingYears           1.320807      -88.630549                -0.020432
# TrainingTimesLastYear      -0.056579        7.161757                -0.005803
# WorkLifeBalance             0.013678        5.322123                 0.019402
# YearsAtCompany              0.451007      -36.157905                 0.104385
# YearsInCurrentRole          0.335552      -40.617268                 0.078144
# YearsSinceLastPromotion     0.189950      -48.575081                 0.122537
# YearsWithCurrManager        0.309968      -13.725879                -0.037061
#
#                            HourlyRate  JobInvolvement     JobLevel  \
# Age                          3.833538        0.160614     5.499858
# DailyRate                  238.047236       13.602559     9.796459
# DistanceFromHome            -1.268295        0.159179     0.020953
# Education                    0.275788        0.037138     0.110753
# EmployeeNumber             401.273207        1.927400   -24.524835
# EnvironmentSatisfaction     -0.858202       -0.012120    -0.006560
# HourlyRate                 419.188531        0.633930    -1.083280
# JobInvolvement               0.633930        0.504307    -0.002042
# JobLevel                    -1.083280       -0.002042     1.251977
# JobSatisfaction             -2.053151       -0.010563    -0.013673
# MonthlyIncome            -3305.561112       -8.826768  5111.230681
# MonthlyRate                124.632474     -290.900999   380.781772
# NumCompaniesWorked           0.459005        0.024954     0.434448
# PercentSalaryHike           -0.274623       -0.061448    -0.077549
# PerformanceRating           -0.017086       -0.011657    -0.003086
# RelationshipSatisfaction    -0.332678        0.029715     0.026216
# StockOptionLevel             0.384718        0.019977    -0.006807
# TotalWorkingYears           -2.476085        0.047578     6.911640
# TrainingTimesLastYear       -0.032703       -0.008967    -0.002144
# WorkLifeBalance             -0.115573       -0.010945     0.040201
# YearsAtCompany              -4.553370       -0.040773     3.699981
# YearsInCurrentRole          -2.096323        0.036619     1.714291
# YearsSinceLastPromotion     -3.734118       -0.087293     1.218503
# YearsWithCurrManager        -2.127511        0.124241     1.440406
#
#                           JobSatisfaction  ...  PerformanceRating  \
# Age                              0.079040  ...           0.025782
# DailyRate                        9.925121  ...           2.707249
# DistanceFromHome                 0.147511  ...           0.130458
# Education                        0.002014  ...          -0.010028
# EmployeeNumber                 -28.712320  ...         -12.073195
# EnvironmentSatisfaction         -0.055230  ...           0.000931
# HourlyRate                      -2.053151  ...          -0.017086
# JobInvolvement                  -0.010563  ...          -0.011657
# JobLevel                        -0.013673  ...          -0.003086
# JobSatisfaction                  1.203165  ...           0.003089
# MonthlyIncome                 -107.617822  ...         -17.701060
# MonthlyRate                    -15.388714  ...         -32.261943
# NumCompaniesWorked              -0.153399  ...           0.005737
# PercentSalaryHike                0.073047  ...           1.039189
# PerformanceRating                0.003089  ...           0.134107
# RelationshipSatisfaction        -0.007551  ...          -0.017664
# StockOptionLevel                 0.007158  ...           0.000162
# TotalWorkingYears               -0.179857  ...           0.064986
# TrainingTimesLastYear            0.004440  ...          -0.006128
# WorkLifeBalance                 -0.031618  ...          -0.006538
# YearsAtCompany                  -0.038883  ...          -0.012254
# YearsInCurrentRole               0.023210  ...           0.043403
# YearsSinceLastPromotion         -0.056049  ...           0.033460
# YearsWithCurrManager            -0.067387  ...           0.019498
#
#                           RelationshipSatisfaction  StockOptionLevel  \
# Age                                       0.633724          0.193061
# DailyRate                                13.131073         17.535145
# DistanceFromHome                          0.130268          0.138119
# Education                                -0.006236          0.023599
# EmployeeNumber                          -39.128226         22.055666
# EnvironmentSatisfaction                  -0.019517          0.005859
# HourlyRate                               -0.332678          0.384718
# JobInvolvement                            0.029715          0.019977
# JobLevel                                  0.026216         -0.006807
# JobSatisfaction                          -0.007551          0.007158
# MonthlyIncome                           169.695728        -32.480709
# MonthlyRate                             -40.047776       -132.269220
# NumCompaniesWorked                        0.086894          0.076372
# PercentSalaryHike                        -0.183772          0.032745
# PerformanceRating                        -0.017664          0.000162
# RelationshipSatisfaction                  1.161583         -0.036704
# StockOptionLevel                         -0.036704          0.765034
# TotalWorkingYears                         0.208776          0.016463
# TrainingTimesLastYear                    -0.003348          0.039069
# WorkLifeBalance                           0.029871          0.017450
# YearsAtCompany                            0.135904          0.062750
# YearsInCurrentRole                       -0.000173          0.179456
# YearsSinceLastPromotion                   0.148960         -0.021523
# YearsWithCurrManager                     -0.023482          0.061349
#
#                           TotalWorkingYears  TrainingTimesLastYear  \
# Age                               51.307847              -0.313929
# DailyRate                         24.198823              11.778118
# DistanceFromHome                  -0.378201              -0.433195
# Education                          1.320807              -0.056579
# EmployeeNumber                   -88.630549               7.161757
# EnvironmentSatisfaction           -0.020432              -0.005803
# HourlyRate                        -2.476085              -0.032703
# JobInvolvement                     0.047578              -0.008967
# JobLevel                           6.911640              -0.002144
# JobSatisfaction                   -0.179857               0.004440
# MonthlyIncome                  29140.331739             -14.698927
# MonthlyRate                     1179.683651             -22.323870
# NumCompaniesWorked                 5.161558              -0.243885
# PercentSalaryHike                  0.088900              -0.016206
# PerformanceRating                  0.064986              -0.006128
# RelationshipSatisfaction           0.208776              -0.003348
# StockOptionLevel                   0.016463               0.039069
# TotalWorkingYears                 61.741582              -0.134268
# TrainingTimesLastYear             -0.134268               1.647119
# WorkLifeBalance                    0.028058               0.027840
# YearsAtCompany                    29.758348               0.119802
# YearsInCurrentRole                13.821420               0.104403
# YearsSinceLastPromotion            9.391882               0.024101
# YearsWithCurrManager              12.407415               0.050881
#
#                           WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# Age                             -0.276014       17.313992            7.610359
# DailyRate                      -15.265970     -104.131306          -28.738166
# DistanceFromHome                -0.123489       -0.132493            0.108279
# Education                        0.013678        0.451007            0.335552
# EmployeeNumber                   5.322123      -36.157905          -40.617268
# EnvironmentSatisfaction          0.019402        0.104385            0.078144
# HourlyRate                      -0.115573       -4.553370           -2.096323
# JobInvolvement                  -0.010945       -0.040773            0.036619
# JobLevel                         0.040201        3.699981            1.714291
# JobSatisfaction                 -0.031618       -0.038883            0.023210
# MonthlyIncome                  136.531512    15283.777253         6955.817209
# MonthlyRate                    -40.316049     -923.621445          417.446691
# NumCompaniesWorked              -0.014452       -1.536449           -0.554455
# PercentSalaryHike               -0.074459       -0.331356            0.137335
# PerformanceRating               -0.006538       -0.012254            0.043403
# RelationshipSatisfaction         0.029871        0.135904           -0.000173
# StockOptionLevel                 0.017450        0.062750            0.179456
# TotalWorkingYears                0.028058       29.758348           13.821420
# TrainingTimesLastYear            0.027840        0.119802            0.104403
# WorkLifeBalance                  0.486196        0.087694            0.136068
# YearsAtCompany                   0.087694       36.824530           17.271137
# YearsInCurrentRole               0.136068       17.271137           13.385316
# YearsSinceLastPromotion          0.072917       11.184876            6.207649
# YearsWithCurrManager            -0.009231       16.240607            9.095044
#
#                           YearsSinceLastPromotion  YearsWithCurrManager
# Age                                      5.387640              6.302237
# DailyRate                              -62.109487            -80.934305
# DistanceFromHome                        -0.667696              0.512384
# Education                                0.189950              0.309968
# EmployeeNumber                         -48.575081            -13.725879
# EnvironmentSatisfaction                  0.122537             -0.037061
# HourlyRate                              -3.734118             -2.127511
# JobInvolvement                          -0.087293              0.124241
# JobLevel                                 1.218503              1.440406
# JobSatisfaction                         -0.056049             -0.067387
# MonthlyIncome                         5166.598232           5682.111108
# MonthlyRate                            219.606559           -560.367489
# NumCompaniesWorked                      -0.201680             -0.801477
# PercentSalaryHike                        0.035958              0.004316
# PerformanceRating                        0.033460              0.019498
# RelationshipSatisfaction                 0.148960             -0.023482
# StockOptionLevel                        -0.021523              0.061349
# TotalWorkingYears                        9.391882             12.407415
# TrainingTimesLastYear                    0.024101              0.050881
# WorkLifeBalance                          0.072917             -0.009231
# YearsAtCompany                          11.184876             16.240607
# YearsInCurrentRole                       6.207649              9.095044
# YearsSinceLastPromotion                  9.663713              5.219147
# YearsWithCurrManager                     5.219147             12.408526
#
# [24 rows x 24 columns]

# %%
plt.figure(figsize=(14,14))  #14in by 14in
sns.heatmap(df.corr(), annot=True, fmt='.0%')

# %%
from pandas.api.types import is_numeric_dtype
target_cols = [col for col in df.columns if 
    is_numeric_dtype(df[col])
]
for col in target_cols:
    df.loc[:, col] = pd.to_numeric(df[col])

# %%
X = df.iloc[:, 0:1].values
y = df.iloc[:, 1]

# %%
X
# Out:
# array([[50.],
#        [36.],
#        [21.],
#        ...,
#        [22.],
#        [29.],
#        [50.]])

# %%
y
# Out:
# 0        No
# 1        No
# 2       Yes
# 3        No
# 4        No
#        ...
# 1024     No
# 1025     No
# 1026    Yes
# 1027     No
# 1028     No
# Name: Attrition, Length: 1029, dtype: object

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.4,random_state =1)

# %%
X_train
# Out:
# array([[33.],
#        [21.],
#        [42.],
#        [29.],
#        [39.],
#        [40.],
#        [nan],
#        [34.],
#        [19.],
#        [42.],
#        [38.],
#        [56.],
#        [37.],
#        [nan],
#        [nan],
#        [30.],
#        [nan],
#        [30.],
#        [44.],
#        [34.],
#        [51.],
#        [33.],
#        [nan],
#        [23.],
#        [27.],
#        [47.],
#        [36.],
#        [38.],
#        [59.],
#        [36.],
#        [44.],
#        [36.],
#        [27.],
#        [39.],
#        [43.],
#        [50.],
#        [24.],
#        [41.],
#        [nan],
#        [55.],
#        [46.],
#        [36.],
#        [41.],
#        [45.],
#        [29.],
#        [30.],
#        [55.],
#        [42.],
#        [46.],
#        [43.],
#        [22.],
#        [33.],
#        [31.],
#        [38.],
#        [34.],
#        [20.],
#        [33.],
#        [20.],
#        [27.],
#        [59.],
#        [44.],
#        [38.],
#        [22.],
#        [39.],
#        [37.],
#        [31.],
#        [29.],
#        [46.],
#        [45.],
#        [32.],
#        [43.],
#        [44.],
#        [37.],
#        [41.],
#        [34.],
#        [24.],
#        [39.],
#        [32.],
#        [36.],
#        [41.],
#        [36.],
#        [40.],
#        [32.],
#        [nan],
#        [37.],
#        [32.],
#        [nan],
#        [29.],
#        [55.],
#        [39.],
#        [32.],
#        [43.],
#        [38.],
#        [33.],
#        [31.],
#        [32.],
#        [45.],
#        [36.],
#        [48.],
#        [27.],
#        [nan],
#        [46.],
#        [37.],
#        [36.],
#        [42.],
#        [46.],
#        [nan],
#        [33.],
#        [31.],
#        [55.],
#        [nan],
#        [38.],
#        [29.],
#        [55.],
#        [38.],
#        [nan],
#        [40.],
#        [40.],
#        [45.],
#        [nan],
#        [nan],
#        [50.],
#        [42.],
#        [34.],
#        [47.],
#        [20.],
#        [40.],
#        [41.],
#        [36.],
#        [37.],
#        [33.],
#        [52.],
#        [23.],
#        [36.],
#        [29.],
#        [33.],
#        [34.],
#        [49.],
#        [54.],
#        [nan],
#        [31.],
#        [34.],
#        [33.],
#        [37.],
#        [27.],
#        [29.],
#        [32.],
#        [23.],
#        [37.],
#        [42.],
#        [41.],
#        [40.],
#        [40.],
#        [23.],
#        [29.],
#        [40.],
#        [36.],
#        [27.],
#        [43.],
#        [27.],
#        [27.],
#        [41.],
#        [33.],
#        [nan],
#        [27.],
#        [29.],
#        [39.],
#        [22.],
#        [nan],
#        [nan],
#        [53.],
#        [41.],
#        [nan],
#        [33.],
#        [32.],
#        [27.],
#        [45.],
#        [53.],
#        [39.],
#        [29.],
#        [nan],
#        [22.],
#        [23.],
#        [30.],
#        [45.],
#        [34.],
#        [38.],
#        [30.],
#        [32.],
#        [34.],
#        [31.],
#        [29.],
#        [29.],
#        [nan],
#        [31.],
#        [58.],
#        [42.],
#        [27.],
#        [56.],
#        [51.],
#        [40.],
#        [38.],
#        [nan],
#        [45.],
#        [39.],
#        [29.],
#        [nan],
#        [52.],
#        [37.],
#        [29.],
#        [45.],
#        [49.],
#        [27.],
#        [32.],
#        [55.],
#        [37.],
#        [51.],
#        [38.],
#        [33.],
#        [45.],
#        [nan],
#        [29.],
#        [50.],
#        [29.],
#        [47.],
#        [34.],
#        [43.],
#        [30.],
#        [31.],
#        [nan],
#        [nan],
#        [nan],
#        [30.],
#        [31.],
#        [34.],
#        [48.],
#        [54.],
#        [40.],
#        [31.],
#        [52.],
#        [29.],
#        [31.],
#        [nan],
#        [58.],
#        [40.],
#        [50.],
#        [56.],
#        [nan],
#        [23.],
#        [29.],
#        [31.],
#        [31.],
#        [36.],
#        [19.],
#        [46.],
#        [34.],
#        [34.],
#        [42.],
#        [46.],
#        [45.],
#        [44.],
#        [24.],
#        [nan],
#        [48.],
#        [27.],
#        [51.],
#        [20.],
#        [57.],
#        [20.],
#        [41.],
#        [31.],
#        [nan],
#        [44.],
#        [nan],
#        [57.],
#        [nan],
#        [34.],
#        [41.],
#        [31.],
#        [29.],
#        [34.],
#        [59.],
#        [50.],
#        [41.],
#        [31.],
#        [29.],
#        [40.],
#        [30.],
#        [29.],
#        [42.],
#        [31.],
#        [45.],
#        [34.],
#        [29.],
#        [30.],
#        [53.],
#        [nan],
#        [36.],
#        [20.],
#        [38.],
#        [36.],
#        [50.],
#        [41.],
#        [30.],
#        [40.],
#        [38.],
#        [42.],
#        [29.],
#        [55.],
#        [33.],
#        [43.],
#        [nan],
#        [37.],
#        [31.],
#        [36.],
#        [43.],
#        [44.],
#        [49.],
#        [51.],
#        [51.],
#        [37.],
#        [55.],
#        [nan],
#        [42.],
#        [40.],
#        [49.],
#        [34.],
#        [37.],
#        [47.],
#        [34.],
#        [nan],
#        [27.],
#        [49.],
#        [18.],
#        [31.],
#        [48.],
#        [30.],
#        [34.],
#        [31.],
#        [40.],
#        [40.],
#        [32.],
#        [38.],
#        [36.],
#        [nan],
#        [56.],
#        [46.],
#        [45.],
#        [23.],
#        [50.],
#        [46.],
#        [30.],
#        [36.],
#        [38.],
#        [nan],
#        [nan],
#        [46.],
#        [42.],
#        [nan],
#        [51.],
#        [49.],
#        [60.],
#        [39.],
#        [54.],
#        [31.],
#        [27.],
#        [nan],
#        [34.],
#        [39.],
#        [38.],
#        [50.],
#        [44.],
#        [32.],
#        [nan],
#        [34.],
#        [37.],
#        [nan],
#        [nan],
#        [36.],
#        [38.],
#        [55.],
#        [29.],
#        [42.],
#        [nan],
#        [nan],
#        [33.],
#        [46.],
#        [29.],
#        [nan],
#        [nan],
#        [36.],
#        [41.],
#        [42.],
#        [30.],
#        [34.],
#        [42.],
#        [30.],
#        [18.],
#        [nan],
#        [43.],
#        [44.],
#        [27.],
#        [29.],
#        [38.],
#        [32.],
#        [34.],
#        [45.],
#        [47.],
#        [37.],
#        [33.],
#        [50.],
#        [27.],
#        [60.],
#        [45.],
#        [52.],
#        [nan],
#        [30.],
#        [45.],
#        [30.],
#        [54.],
#        [34.],
#        [27.],
#        [52.],
#        [49.],
#        [19.],
#        [30.],
#        [nan],
#        [41.],
#        [31.],
#        [21.],
#        [nan],
#        [nan],
#        [27.],
#        [34.],
#        [46.],
#        [nan],
#        [29.],
#        [45.],
#        [34.],
#        [50.],
#        [27.],
#        [30.],
#        [31.],
#        [nan],
#        [23.],
#        [nan],
#        [38.],
#        [46.],
#        [nan],
#        [54.],
#        [nan],
#        [37.],
#        [34.],
#        [58.],
#        [37.],
#        [nan],
#        [49.],
#        [36.],
#        [nan],
#        [nan],
#        [46.],
#        [nan],
#        [42.],
#        [30.],
#        [29.],
#        [32.],
#        [33.],
#        [36.],
#        [40.],
#        [42.],
#        [48.],
#        [40.],
#        [29.],
#        [36.],
#        [55.],
#        [43.],
#        [32.],
#        [54.],
#        [42.],
#        [34.],
#        [38.],
#        [40.],
#        [43.],
#        [46.],
#        [nan],
#        [34.],
#        [42.],
#        [22.],
#        [39.],
#        [29.],
#        [22.],
#        [56.],
#        [51.],
#        [41.],
#        [20.],
#        [27.],
#        [nan],
#        [nan],
#        [nan],
#        [27.],
#        [34.],
#        [45.],
#        [31.],
#        [46.],
#        [nan],
#        [27.],
#        [57.],
#        [24.],
#        [41.],
#        [41.],
#        [31.],
#        [51.],
#        [41.],
#        [nan],
#        [40.],
#        [40.],
#        [32.],
#        [42.],
#        [45.],
#        [45.],
#        [36.],
#        [41.],
#        [30.],
#        [nan],
#        [59.],
#        [30.],
#        [38.],
#        [32.],
#        [nan],
#        [42.],
#        [37.],
#        [19.],
#        [nan],
#        [36.],
#        [42.],
#        [37.],
#        [32.],
#        [nan],
#        [32.],
#        [36.],
#        [36.],
#        [40.],
#        [43.],
#        [38.],
#        [37.],
#        [23.],
#        [46.],
#        [54.],
#        [29.],
#        [56.],
#        [30.],
#        [24.],
#        [nan],
#        [29.],
#        [32.],
#        [31.],
#        [43.],
#        [nan],
#        [32.],
#        [27.],
#        [27.],
#        [44.],
#        [38.],
#        [30.],
#        [33.],
#        [33.],
#        [44.],
#        [39.],
#        [54.],
#        [45.],
#        [34.],
#        [30.],
#        [33.],
#        [33.],
#        [50.],
#        [31.],
#        [nan],
#        [38.],
#        [56.],
#        [50.],
#        [22.],
#        [34.],
#        [30.],
#        [27.],
#        [37.],
#        [nan],
#        [30.],
#        [33.],
#        [53.],
#        [31.],
#        [51.],
#        [59.],
#        [nan],
#        [50.],
#        [34.],
#        [31.],
#        [31.],
#        [52.],
#        [29.],
#        [nan],
#        [30.],
#        [nan],
#        [31.],
#        [53.],
#        [nan],
#        [40.],
#        [34.],
#        [nan],
#        [38.],
#        [nan],
#        [nan],
#        [nan],
#        [24.],
#        [37.],
#        [31.],
#        [58.],
#        [22.]])

# %%
y_train
# Out:
# 14     Yes
# 375    Yes
# 82      No
# 593     No
# 719     No
#       ...
# 960     No
# 847    Yes
# 715    Yes
# 905     No
# 235    Yes
# Name: Attrition, Length: 617, dtype: object

# %%
X_train.shape
# Out:
# (617, 1)

# %%
y_train.shape
# Out:
# (617,)

# %%
model
# Out:
# LinearRegression()
